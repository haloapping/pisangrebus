# %% [markdown]
# # Iris Dataset: EDA, Data Visualisation, and Classification
# About dataset: [https://en.wikipedia.org/wiki/Iris_flower_data_set](https://en.wikipedia.org/wiki/Iris_flower_data_set) <br/>
# ![iris](./img/iris_dataset.png)

# %% [markdown]
# ## Video Workshop
# Panduan dan pembahasan materi worskhop ini bisa diakses melalui video berikut ini:

# %% [markdown]
# ## Import Module

# %%
import pandas as pd
from IPython.core.display import HTML
HTML(
    """
        <style>
            .output_png {
                display: table-cell;
                text-align: center;
                vertical-align: middle;
            }
        </style>
    """
)
# Out:
#         <style>
#             .output_png {
#                 display: table-cell;
#                 text-align: center;
#                 vertical-align: middle;
#             }
#         </style>

# %% [markdown]
# ## Initialize and Load Dataset

# %%
iris_df = pd.read_csv('./dataset/iris/Iris.csv')
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Drop Column id

# %%
iris_df.drop(columns='Id', inplace=True)
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Identify the Shape of the Dataet

# %%
print(f"Number of row: {iris_df.shape[0]}")
print(f"Number of column: {iris_df.shape[1]}")
# Out:
# Number of row: 150
# Number of column: 5

# %% [markdown]
# ### Get the List of Columns

# %%
iris_df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### Identitfy Data Types for each Column

# %%
iris_df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# ### Identify missing values

# %%
iris_df.isna().values.any()
# Out:
# False

# %%
iris_df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### Identify Duplicate Entries/Rows

# %%
iris_df[iris_df.duplicated()] #menampilkan hanya data duplikat sekunder
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 142            5.8           2.7            5.1           1.9  Iris-virginica

# %%
iris_df[iris_df.duplicated(keep=False)] #menampilkan semua data duplikat
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 101            5.8           2.7            5.1           1.9  Iris-virginica
# 142            5.8           2.7            5.1           1.9  Iris-virginica

# %%
iris_df.duplicated().value_counts()
# Out:
# False    147
# True       3
# dtype: int64

# %% [markdown]
# ### Drop Duplicate Entries/Rows

# %%
iris_df.drop_duplicates(inplace=True)
iris_df.shape
# Out:
# (147, 5)

# %% [markdown]
# ### Describe Dataset

# %%
iris_df.describe(include='all')
# Out:
#         SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count      147.000000    147.000000     147.000000    147.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean         5.856463      3.055782       3.780272      1.208844
# std          0.829100      0.437009       1.759111      0.757874
# min          4.300000      2.000000       1.000000      0.100000
# 25%          5.100000      2.800000       1.600000      0.300000
# 50%          5.800000      3.000000       4.400000      1.300000
# 75%          6.400000      3.300000       5.100000      1.800000
# max          7.900000      4.400000       6.900000      2.500000
#
#                 Species
# count               147
# unique                3
# top     Iris-versicolor
# freq                 50
# mean                NaN
# std                 NaN
# ...

# %% [markdown]
# ### Correlation Matrix

# %%
iris_df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109321       0.871305      0.817058
# SepalWidthCm       -0.109321      1.000000      -0.421057     -0.356376
# PetalLengthCm       0.871305     -0.421057       1.000000      0.961883
# PetalWidthCm        0.817058     -0.356376       0.961883      1.000000

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Import Modules

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(data=iris_df.corr(), annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Plot

# %%
label = list(iris_df['Species'].value_counts())

# %%
iris_df['Species'].value_counts().plot.bar()
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=iris_df, x='Species')
plt.tight_layout()

# %% [markdown]
# ### Pie Chart

# %%
iris_df['Species'].value_counts().plot.pie(figsize=(6, 6), autopct='%1.1f%%', labels=None, legend=True)
plt.tight_layout()

# %% [markdown]
# ### Line Plot

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

iris_df['SepalLengthCm'].plot.line(ax=ax[0][0])
ax[0][0].set_title('Sepal Length')

iris_df['SepalWidthCm'].plot.line(ax=ax[0][1])
ax[0][1].set_title('Sepal Width')

iris_df.PetalLengthCm.plot.line(ax=ax[1][0])
ax[1][0].set_title('Petal Length')

iris_df.PetalWidthCm.plot.line(ax=ax[1][1])
ax[1][1].set_title('Petal Width')
# Out:
# Text(0.5, 1.0, 'Petal Width')

# %%
iris_df.plot()
plt.tight_layout()

# %% [markdown]
# ### Histogram

# %%
iris_df.hist(figsize=(6, 6), bins=6)
plt.tight_layout()

# %%
iris_df.hist(figsize=(20, 10), bins=10)
plt.tight_layout()

# %% [markdown]
# ### Box Plot

# %%
iris_df.boxplot()
plt.tight_layout()

# %%
iris_df.boxplot(by='Species', figsize=(8, 8))
plt.tight_layout()

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris_df, hue='Species')
plt.tight_layout()

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(iris_df, hue='Species', markers='+')
plt.tight_layout()

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(data=iris_df, x='SepalLengthCm', y='Species', inner='quartile')
plt.tight_layout()

# %% [markdown]
# ## Iris Dataset: Classification Models

# %% [markdown]
# ### Import Modules

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ### Select Feature and Class Label

# %%
X = iris_df.drop(columns='Species')
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y = iris_df['Species']
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# ### Split dataset into a training set dan a testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.6, test_size=0.4, random_state=10)

# %%
print('Training dataset')
print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)

print('\nTest dataset')
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)
# Out:
# Training dataset
# X_train:  (88, 4)
# y_train:  (88,)
#
# Test dataset
# X_test:  (59, 4)
# y_test:  (59,)

# %% [markdown]
# ### K-Nearest-Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range = list(range(1, 26))
scores = []

for k in k_range:
    model_knn = KNeighborsClassifier(n_neighbors=k)
    model_knn.fit(X_train, y_train)
    y_pred = model_knn.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))

# %%
plt.plot(k_range, scores)
plt.xlabel("Value of k for KNN")
plt.ylabel("Accuracy Score")
plt.title("Accuracy Scores for Values of k of K-Nearest-Neighbors")
plt.tight_layout()
plt.show()

# %%
model_knn = KNeighborsClassifier(n_neighbors=3)
model_knn.fit(X_train, y_train)
y_pred = model_knn.predict(X_test)

# %%
y_test.shape
# Out:
# (59,)

# %%
y_pred.shape
# Out:
# (59,)

# %% [markdown]
# #### Accuracy Score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9322033898305084

# %% [markdown]
# #### Confusion Matrix

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[18  0  0]
#  [ 0 19  2]
#  [ 0  2 18]]

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.90      0.90      0.90        21
#  Iris-virginica       0.90      0.90      0.90        20
#
#        accuracy                           0.93        59
#       macro avg       0.93      0.93      0.93        59
#    weighted avg       0.93      0.93      0.93        59

# %% [markdown]
# #### Test Prediction

# %%
iris_df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
model_knn.predict_proba([[6.7, 1.0, 5.2, 2.3]])
# Out:
# array([[0.        , 0.33333333, 0.66666667]])

# %%
model_knn.predict([[6.7, 1.0, 5.2, 2.3]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_logreg = LogisticRegression(solver="lbfgs", multi_class="auto")
model_logreg.fit(X_train, y_train)
y_pred = model_logreg.predict(X_test)

# %% [markdown]
# #### Accuracy Score

# %%
print("Accuracy:", accuracy_score(y_pred, y_test))
# Out:
# Accuracy: 0.9322033898305084

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[18  0  0]
#  [ 0 20  1]
#  [ 0  3 17]]

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.87      0.95      0.91        21
#  Iris-virginica       0.94      0.85      0.89        20
#
#        accuracy                           0.93        59
#       macro avg       0.94      0.93      0.93        59
#    weighted avg       0.93      0.93      0.93        59

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
model_svc = SVC(gamma="scale")
model_svc.fit(X_train, y_train)
y_pred = model_svc.predict(X_test)

# %% [markdown]
# #### Accuracy Score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9661016949152542

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[18  0  0]
#  [ 0 21  0]
#  [ 0  2 18]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.91      1.00      0.95        21
#  Iris-virginica       1.00      0.90      0.95        20
#
#        accuracy                           0.97        59
#       macro avg       0.97      0.97      0.97        59
#    weighted avg       0.97      0.97      0.97        59

# %%
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
model_svc.predict([[5.1, 3.5, 1.4, 0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
y_pred = model_dt.predict(X_test)

# %% [markdown]
# #### Accuracy Score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9491525423728814

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[18  0  0]
#  [ 0 20  1]
#  [ 0  2 18]]

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.91      0.95      0.93        21
#  Iris-virginica       0.95      0.90      0.92        20
#
#        accuracy                           0.95        59
#       macro avg       0.95      0.95      0.95        59
#    weighted avg       0.95      0.95      0.95        59

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators=100)
model_rf.fit(X_train, y_train)
y_pred = model_rf.predict(X_test)

# %% [markdown]
# #### Accuracy Score

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9491525423728814

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[18  0  0]
#  [ 0 20  1]
#  [ 0  2 18]]

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.91      0.95      0.93        21
#  Iris-virginica       0.95      0.90      0.92        20
#
#        accuracy                           0.95        59
#       macro avg       0.95      0.95      0.95        59
#    weighted avg       0.95      0.95      0.95        59

# %% [markdown]
# ### Accuracy Comparison for Various Models

# %%
models          = [model_knn, model_logreg, model_svc, model_dt, model_rf]
model_names     = ['KNN', 'LogReg', 'SVC', 'Decision Tree', 'Random Forest']
accuracy_scores = []

for model in models:
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    
for model_name, accuracy_score in zip(model_names ,accuracy_scores):
    print(f"{model_name}\t:{accuracy_score}")
# Out:
# KNN	:0.9322033898305084
# LogReg	:0.9322033898305084
# SVC	:0.9661016949152542
# Decision Tree	:0.9491525423728814
# Random Forest	:0.9491525423728814

# %%
plt.bar(["KNN", "LogReg", "SVC", "Decision Tree", "Random Forest"], accuracy_scores)
plt.ylim(0.90, 1.01)
plt.title("Accuracy Comparison for Various Model")
plt.xlabel("Model")
plt.ylabel("Accuracy Score")
plt.tight_layout()
plt.show()
